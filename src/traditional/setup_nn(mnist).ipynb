# %%
import tensorflow as tf
import matplotlib.pyplot as plt
#load data
print(tf.__version__)
mnist = tf.keras.datasets.mnist
(x_train, y_train),(x_test, y_test) = mnist.load_data("/home/super-workstation/program/deep-learning/MNIST_data/mnist.npz")
x_train, x_test = x_train/255.0, x_test/255.0
print(y_train.shape)
# Out:
# 1.14.0
# (60000,)

# %%
# setup network 仅有全连接 32
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D
from keras import optimizers

model = Sequential()
model.add(Flatten(input_shape=(28,28))) # 展开
print(model.output_shape)
model.add(Dense(32, activation='relu')) # 全连接(隐藏层1)
print(model.output_shape)
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax')) # 输出
print(model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=["accuracy"]) # 编译

# train model
print(y_train.shape)
model.fit(x_train, y_train, epochs=5)
# Out:
# (None, 784)
# (None, 32)
# (None, 10)
# (60000,)
# Epoch 1/5
# 60000/60000 [==============================] - 3s 52us/step - loss: 1.1539 - acc: 0.6260
# Epoch 2/5
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.7263 - acc: 0.7716
# Epoch 3/5
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.6385 - acc: 0.7981
# Epoch 4/5
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.5945 - acc: 0.8132
# Epoch 5/5
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.5725 - acc: 0.8220

# %%
# setup network 仅有全连接 64
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D
from keras.optimizers import SGD

model = Sequential()
model.add(Flatten(input_shape=(28,28))) # 展开
print(model.output_shape)
model.add(Dense(64, activation='relu')) # 全连接(隐藏层1)
print(model.output_shape)
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax')) # 输出
print(model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=["accuracy"]) # 编译

# train model
print(y_train.shape)
model.fit(x_train, y_train, epochs=5)
# Out:
# (None, 784)
# (None, 64)
# (None, 10)
# (60000,)
# Epoch 1/5
# 60000/60000 [==============================] - 3s 51us/step - loss: 0.9701 - acc: 0.7031
# Epoch 2/5
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.5530 - acc: 0.8374
# Epoch 3/5
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.4752 - acc: 0.8609
# Epoch 4/5
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.4265 - acc: 0.8765
# Epoch 5/5
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.3997 - acc: 0.8834

# %%
# setup network 仅有全连接 128
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D
from keras.optimizers import SGD
import datetime,time

model = Sequential()
model.add(Flatten(input_shape=(28,28))) # 展开
print(model.output_shape)
model.add(Dense(128, activation='relu')) # 全连接(隐藏层1)
print(model.output_shape)
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax')) # 输出
print(model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=["accuracy"]) # 编译

# train model
print(y_train.shape)
start_t = datetime.datetime.now()
model.fit(x_train, y_train, epochs=5)
end_t = datetime.datetime.now()
print(end_t-start_t)
# Out:
# (None, 784)
# (None, 128)
# (None, 10)
# (60000,)
# Epoch 1/5
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.8408 - acc: 0.7485
# Epoch 2/5
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.4691 - acc: 0.8649
# Epoch 3/5
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.3935 - acc: 0.8869
# Epoch 4/5
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.3513 - acc: 0.9006
# Epoch 5/5
# 60000/60000 [==============================] - 3s 52us/step - loss: 0.3236 - acc: 0.9073
# 0:00:13.361511

# %%
# setup network 仅有全连接 256
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D
from keras.optimizers import SGD
import datetime,time

model = Sequential()
model.add(Flatten(input_shape=(28,28))) # 展开
print(model.output_shape)
model.add(Dense(256, activation='relu')) # 全连接(隐藏层1)
print(model.output_shape)
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax')) # 输出
print(model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=["accuracy"]) # 编译

# train model
print(y_train.shape)
start_t = datetime.datetime.now()
model.fit(x_train, y_train, epochs=5)
end_t = datetime.datetime.now()
print(end_t-start_t)
# Out:
# (None, 784)
# (None, 256)
# (None, 10)
# (60000,)
# Epoch 1/5
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.7579 - acc: 0.7780
# Epoch 2/5
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.4170 - acc: 0.8802
# Epoch 3/5
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.3474 - acc: 0.8996
# Epoch 4/5
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.3061 - acc: 0.9130
# Epoch 5/5
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.2786 - acc: 0.9208
# 0:00:13.007896

# %%
# setup network 仅有全连接 512
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D
from keras.optimizers import SGD
import datetime,time

model = Sequential()
model.add(Flatten(input_shape=(28,28))) # 展开
print(model.output_shape)
model.add(Dense(512, activation='relu')) # 全连接(隐藏层1)
print(model.output_shape)
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax')) # 输出
print(model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=["accuracy"]) # 编译

# train model
print(y_train.shape)
start_t = datetime.datetime.now()
model.fit(x_train, y_train, epochs=5)
end_t = datetime.datetime.now()
print(end_t-start_t)
# Out:
# (None, 784)
# (None, 512)
# (None, 10)
# (60000,)
# Epoch 1/5
# 60000/60000 [==============================] - 3s 51us/step - loss: 0.6956 - acc: 0.8082
# Epoch 2/5
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.3762 - acc: 0.8919
# Epoch 3/5
# 60000/60000 [==============================] - 3s 53us/step - loss: 0.3134 - acc: 0.9106
# Epoch 4/5
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.2756 - acc: 0.9222
# Epoch 5/5
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.2494 - acc: 0.9291
# 0:00:14.221054

# %%
# setup network 仅有全连接 1024
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D
from keras.optimizers import SGD
import datetime,time

model = Sequential()
model.add(Flatten(input_shape=(28,28))) # 展开
print(model.output_shape)
model.add(Dense(1024, activation='relu')) # 全连接(隐藏层1)
print(model.output_shape)
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax')) # 输出
print(model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=["accuracy"]) # 编译

# train model
print(y_train.shape)
start_t = datetime.datetime.now()
model.fit(x_train, y_train, epochs=5)
end_t = datetime.datetime.now()
print(end_t-start_t)
# Out:
# (None, 784)
# (None, 1024)
# (None, 10)
# (60000,)
# Epoch 1/5
# 60000/60000 [==============================] - 4s 64us/step - loss: 0.6381 - acc: 0.8299
# Epoch 2/5
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.3531 - acc: 0.8989
# Epoch 3/5
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.2966 - acc: 0.9155
# Epoch 4/5
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.2606 - acc: 0.9256
# Epoch 5/5
# 60000/60000 [==============================] - 3s 57us/step - loss: 0.2361 - acc: 0.9338
# 0:00:18.556337

# %%
# setup network 卷积+全连接 32 + 1024
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D
from keras.optimizers import SGD
import datetime,time

model = Sequential()
model.add(Conv2D(32, (3,3), padding='same', input_shape=(28,28,1)))
model.add(Flatten()) # 展开
print(model.output_shape)
model.add(Dense(1024, activation='relu')) # 全连接(隐藏层1)
print(model.output_shape)
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax')) # 输出
print(model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=["accuracy"]) # 编译

# train model
import numpy as np
#np.reshape(x_train, (x_train.shape[0], x_train.shape[1], x_train.shape[2], 1))
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
print(x_train.shape)
start_t = datetime.datetime.now()
model.fit(x_train, y_train, epochs=5)
end_t = datetime.datetime.now()
print(end_t-start_t)

# evaluate
x_test = x_test.reshape(x_test.shape[0], x_train.shape[1], x_train.shape[2], 1)
loss_and_acc = model.evaluate(x_test, y_test)
print("loss: ", loss_and_acc[0])
print("accuracy: ", loss_and_acc[1])
# Out:
# (None, 25088)
# (None, 1024)
# (None, 10)

# %%
# setup network 卷积32
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D
from keras.optimizers import SGD
import datetime,time

model = Sequential()
model.add(Conv2D(32, (3,3), padding='same', input_shape=(28,28,1)))
print(model.output_shape)
model.add(Dropout(0.5))
model.add(Flatten()) # 展开
print(model.output_shape)
model.add(Dense(10, activation='softmax')) # 输出
print(model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=["accuracy"]) # 编译

# train model
import numpy as np
#np.reshape(x_train, (x_train.shape[0], x_train.shape[1], x_train.shape[2], 1))
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
print(x_train.shape)
start_t = datetime.datetime.now()
model.fit(x_train, y_train, epochs=5)
end_t = datetime.datetime.now()
print("cost time: ", end_t-start_t)

# evaluate
x_test = x_test.reshape(x_test.shape[0], x_train.shape[1], x_train.shape[2], 1)
loss_and_acc = model.evaluate(x_test, y_test)
print("loss: ", loss_and_acc[0])
print("accuracy: ", loss_and_acc[1])
# Out:
# (None, 28, 28, 32)
# (None, 10)
# (60000, 28, 28, 1)
# Epoch 1/5
# 60000/60000 [==============================] - 7s 117us/step - loss: 0.4420 - acc: 0.8751
# Epoch 2/5
# 60000/60000 [==============================] - 6s 107us/step - loss: 0.3264 - acc: 0.9046
# Epoch 3/5
# 60000/60000 [==============================] - 6s 96us/step - loss: 0.3127 - acc: 0.9107
# Epoch 4/5
# 60000/60000 [==============================] - 5s 89us/step - loss: 0.3040 - acc: 0.9135
# Epoch 5/5
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.2981 - acc: 0.9151
# 0:00:30.291930
# 10000/10000 [==============================] - 1s 51us/step
# loss:  0.28241336252093313
# accuracy:  0.9208

# %%
# setup network 卷积+全连接 32 + 1024
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D
from keras.optimizers import SGD
import datetime,time

model = Sequential()
model.add(Conv2D(32, (3,3), padding='same', input_shape=(28,28,1)))
print("conv2d_1: ", model.output_shape)
model.add(Dropout(0.25))
model.add(Flatten()) # 展开
print("Flatten: ", model.output_shape)
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
print("dense_1: ", model.output_shape)
model.add(Dense(10, activation='softmax')) # 输出
print("output: ", model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=["accuracy"]) # 编译

# train model
import numpy as np
#np.reshape(x_train, (x_train.shape[0], x_train.shape[1], x_train.shape[2], 1))
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
print(x_train.shape)
start_t = datetime.datetime.now()
model.fit(x_train, y_train, epochs=5)
end_t = datetime.datetime.now()
print("cost time: ", end_t-start_t)

# evaluate
x_test = x_test.reshape(x_test.shape[0], x_train.shape[1], x_train.shape[2], 1)
loss_and_acc = model.evaluate(x_test, y_test)
print("loss: ", loss_and_acc[0])
print("accuracy: ", loss_and_acc[1])
# Out:
# conv2d_1:  (None, 28, 28, 32)
# Flatten:  (None, 25088)
# dense_1:  (None, 1024)
# output:  (None, 10)
# (60000, 28, 28, 1)
# Epoch 1/5
# 60000/60000 [==============================] - 19s 318us/step - loss: 0.3840 - acc: 0.8892
# Epoch 2/5
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.1825 - acc: 0.9465
# Epoch 3/5
# 60000/60000 [==============================] - 20s 326us/step - loss: 0.1400 - acc: 0.9588
# Epoch 4/5
# 60000/60000 [==============================] - 18s 303us/step - loss: 0.1179 - acc: 0.9645
# Epoch 5/5
# 60000/60000 [==============================] - 18s 306us/step - loss: 0.1020 - acc: 0.9691
# cost time:  0:01:35.088924
# 10000/10000 [==============================] - 1s 77us/step
# loss:  0.07523823117129505
# accuracy:  0.9765

# %%
# setup network 卷积+全连接 32 + 1024 no Dropout
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D
from keras.optimizers import SGD
import datetime,time

model = Sequential()
model.add(Conv2D(32, (3,3), padding='same', input_shape=(28,28,1)))
print("conv2d_1: ", model.output_shape)
#model.add(Dropout(0.25))
model.add(Flatten()) # 展开
print("Flatten: ", model.output_shape)
model.add(Dense(1024, activation='relu'))
#model.add(Dropout(0.5))
print("dense_1: ", model.output_shape)
model.add(Dense(10, activation='softmax')) # 输出
print("output: ", model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=["accuracy"]) # 编译

# train model
import numpy as np
#np.reshape(x_train, (x_train.shape[0], x_train.shape[1], x_train.shape[2], 1))
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
print(x_train.shape)
start_t = datetime.datetime.now()
model.fit(x_train, y_train, epochs=5)
end_t = datetime.datetime.now()
print("cost time: ", end_t-start_t)

# evaluate
x_test = x_test.reshape(x_test.shape[0], x_train.shape[1], x_train.shape[2], 1)
loss_and_acc = model.evaluate(x_test, y_test)
print("loss: ", loss_and_acc[0])
print("accuracy: ", loss_and_acc[1])
# Out:
# conv2d_1:  (None, 28, 28, 32)
# Flatten:  (None, 25088)
# dense_1:  (None, 1024)
# output:  (None, 10)
# (60000, 28, 28, 1)
# Epoch 1/5
# 60000/60000 [==============================] - 17s 283us/step - loss: 0.3435 - acc: 0.9078
# Epoch 2/5
# 60000/60000 [==============================] - 17s 287us/step - loss: 0.1504 - acc: 0.9555
# Epoch 3/5
# 60000/60000 [==============================] - 16s 271us/step - loss: 0.1055 - acc: 0.9693
# Epoch 4/5
# 60000/60000 [==============================] - 15s 254us/step - loss: 0.0820 - acc: 0.9757
# Epoch 5/5
# 60000/60000 [==============================] - 15s 255us/step - loss: 0.0668 - acc: 0.9806
# cost time:  0:01:21.133625
# 10000/10000 [==============================] - 1s 69us/step
# loss:  0.07183113631810993
# accuracy:  0.977

# %%
# setup network 卷积+卷积+全连接 32+32 + 1024
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D
from keras.optimizers import SGD
import datetime,time

model = Sequential()
model.add(Conv2D(32, (3,3), padding='same', input_shape=(28,28,1)))
print("conv2d_1: ", model.output_shape)
model.add(Conv2D(32, (3,3), padding='same'))
print("conv2d_2: ", model.output_shape)
#model.add(Dropout(0.25))
model.add(Flatten()) # 展开
print("Flatten: ", model.output_shape)
model.add(Dense(1024, activation='relu'))
#model.add(Dropout(0.5))
print("dense_1: ", model.output_shape)
model.add(Dense(10, activation='softmax')) # 输出
print("output: ", model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=["accuracy"]) # 编译

# train model
import numpy as np
#np.reshape(x_train, (x_train.shape[0], x_train.shape[1], x_train.shape[2], 1))
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
print(x_train.shape)
start_t = datetime.datetime.now()
model.fit(x_train, y_train, epochs=5)
end_t = datetime.datetime.now()
print("cost time: ", end_t-start_t)

# evaluate
x_test = x_test.reshape(x_test.shape[0], x_train.shape[1], x_train.shape[2], 1)
loss_and_acc = model.evaluate(x_test, y_test)
print("loss: ", loss_and_acc[0])
print("accuracy: ", loss_and_acc[1])
# Out:
# conv2d_1:  (None, 28, 28, 32)
# conv2d_1:  (None, 28, 28, 32)
# Flatten:  (None, 25088)
# dense_1:  (None, 1024)
# output:  (None, 10)
# (60000, 28, 28, 1)
# Epoch 1/5
# 60000/60000 [==============================] - 18s 296us/step - loss: 0.2463 - acc: 0.9290
# Epoch 2/5
# 60000/60000 [==============================] - 15s 246us/step - loss: 0.1002 - acc: 0.9697
# Epoch 3/5
# 60000/60000 [==============================] - 18s 294us/step - loss: 0.0730 - acc: 0.9770
# Epoch 4/5
# 60000/60000 [==============================] - 18s 292us/step - loss: 0.0550 - acc: 0.9829
# Epoch 5/5
# 60000/60000 [==============================] - 17s 282us/step - loss: 0.0438 - acc: 0.9859
# cost time:  0:01:24.748335
# 10000/10000 [==============================] - 1s 70us/step
# loss:  0.06274145298125222
# accuracy:  0.981

# %%
# setup network 卷积+卷积+全连接 32+32 + 1024
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPool2D
from keras.optimizers import SGD
import datetime,time

model = Sequential()
model.add(Conv2D(32, (3,3), padding='same',  activation='relu', input_shape=(28,28,1)))
print("conv2d_1: ", model.output_shape)
model.add(Conv2D(32, (3,3), padding='same', activation='relu'))
print("conv2d_2: ", model.output_shape)
model.add(Dropout(0.25))
model.add(Flatten()) # 展开
print("Flatten: ", model.output_shape)
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
print("dense_1: ", model.output_shape)
model.add(Dense(10, activation='softmax')) # 输出
print("output: ", model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=["accuracy"]) # 编译

# train model
import numpy as np
#np.reshape(x_train, (x_train.shape[0], x_train.shape[1], x_train.shape[2], 1))
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
print(x_train.shape)
start_t = datetime.datetime.now()
model.fit(x_train, y_train, epochs=5)
end_t = datetime.datetime.now()
print("cost time: ", end_t-start_t)

# evaluate
x_test = x_test.reshape(x_test.shape[0], x_train.shape[1], x_train.shape[2], 1)
loss_and_acc = model.evaluate(x_test, y_test)
print("loss: ", loss_and_acc[0])
print("accuracy: ", loss_and_acc[1])
# Out:
# conv2d_1:  (None, 28, 28, 32)
# conv2d_2:  (None, 28, 28, 64)
# Flatten:  (None, 50176)
# dense_1:  (None, 1024)
# output:  (None, 10)
# (60000, 28, 28, 1)
# Epoch 1/5
# 60000/60000 [==============================] - 29s 485us/step - loss: 0.3514 - acc: 0.8935
# Epoch 2/5
# 60000/60000 [==============================] - 27s 457us/step - loss: 0.1692 - acc: 0.9494
# Epoch 3/5
# 60000/60000 [==============================] - 27s 454us/step - loss: 0.1305 - acc: 0.9598
# Epoch 4/5
# 60000/60000 [==============================] - 27s 456us/step - loss: 0.1110 - acc: 0.9651
# Epoch 5/5
# 60000/60000 [==============================] - 27s 449us/step - loss: 0.0952 - acc: 0.9705
# cost time:  0:02:18.151716
# 10000/10000 [==============================] - 1s 119us/step
# loss:  0.06486002659825608
# accuracy:  0.9791

# %%
# setup network 卷积+卷积+全连接 32+32 + 1024 epochs=10
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPool2D
from keras.optimizers import SGD
import datetime,time

model = Sequential()
model.add(Conv2D(32, (3,3), padding='same',  activation='relu', input_shape=(28,28,1)))
print("conv2d_1: ", model.output_shape)
model.add(Conv2D(32, (3,3), padding='same', activation='relu'))
print("conv2d_2: ", model.output_shape)
model.add(Dropout(0.25))
model.add(Flatten()) # 展开
print("Flatten: ", model.output_shape)
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
print("dense_1: ", model.output_shape)
model.add(Dense(10, activation='softmax')) # 输出
print("output: ", model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=["accuracy"]) # 编译

# train model
import numpy as np
#np.reshape(x_train, (x_train.shape[0], x_train.shape[1], x_train.shape[2], 1))
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
print(x_train.shape)
start_t = datetime.datetime.now()
model.fit(x_train, y_train, epochs=12)
end_t = datetime.datetime.now()
print("cost time: ", end_t-start_t)

# evaluate
x_test = x_test.reshape(x_test.shape[0], x_train.shape[1], x_train.shape[2], 1)
loss_and_acc = model.evaluate(x_test, y_test)
print("loss: ", loss_and_acc[0])
print("accuracy: ", loss_and_acc[1])
# Out:
# conv2d_1:  (None, 28, 28, 32)
# conv2d_2:  (None, 28, 28, 32)
# Flatten:  (None, 25088)
# dense_1:  (None, 1024)
# output:  (None, 10)
# (60000, 28, 28, 1)
# Epoch 1/12
# 60000/60000 [==============================] - 21s 353us/step - loss: 0.3722 - acc: 0.8878
# Epoch 2/12
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.1729 - acc: 0.9471
# Epoch 3/12
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.1341 - acc: 0.9595
# Epoch 4/12
# 60000/60000 [==============================] - 19s 323us/step - loss: 0.1120 - acc: 0.9652
# Epoch 5/12
# 60000/60000 [==============================] - 19s 323us/step - loss: 0.0980 - acc: 0.9691
# Epoch 6/12
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0873 - acc: 0.9724
# Epoch 7/12
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.0782 - acc: 0.9762
# Epoch 8/12
# ...

# %%
# setup network 卷积+卷积+全连接 32+64 + 1024 epochs=12
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPool2D
from keras.optimizers import SGD
import datetime,time

model = Sequential()
model.add(Conv2D(32, (3,3), padding='same',  activation='relu', input_shape=(28,28,1)))
print("conv2d_1: ", model.output_shape)
model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
print("conv2d_2: ", model.output_shape)
#model.add(MaxPool2D(pool_size=(2,2)))
#print("max_pool_1: ", model.output_shape)
model.add(Dropout(0.25))
model.add(Flatten()) # 展开
print("Flatten: ", model.output_shape)
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
print("dense_1: ", model.output_shape)
model.add(Dense(10, activation='softmax')) # 输出
print("output: ", model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=["accuracy"]) # 编译

# train model
import numpy as np
#np.reshape(x_train, (x_train.shape[0], x_train.shape[1], x_train.shape[2], 1))
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
print(x_train.shape)
start_t = datetime.datetime.now()
model.fit(x_train, y_train, epochs=12)
end_t = datetime.datetime.now()
print("cost time: ", end_t-start_t)

# evaluate
x_test = x_test.reshape(x_test.shape[0], x_train.shape[1], x_train.shape[2], 1)
loss_and_acc = model.evaluate(x_test, y_test)
print("loss: ", loss_and_acc[0])
print("accuracy: ", loss_and_acc[1])
# Out:
# conv2d_1:  (None, 28, 28, 32)
# conv2d_2:  (None, 28, 28, 64)
# Flatten:  (None, 50176)
# dense_1:  (None, 1024)
# output:  (None, 10)
# (60000, 28, 28, 1)
# Epoch 1/12
# 60000/60000 [==============================] - 28s 473us/step - loss: 0.3733 - acc: 0.8894
# Epoch 2/12
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.1627 - acc: 0.9509
# Epoch 3/12
# 60000/60000 [==============================] - 27s 456us/step - loss: 0.1255 - acc: 0.9614
# Epoch 4/12
# 60000/60000 [==============================] - 27s 458us/step - loss: 0.1023 - acc: 0.9690
# Epoch 5/12
# 60000/60000 [==============================] - 27s 458us/step - loss: 0.0855 - acc: 0.9740
# Epoch 6/12
# 60000/60000 [==============================] - 28s 461us/step - loss: 0.0748 - acc: 0.9771
# Epoch 7/12
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0652 - acc: 0.9802
# Epoch 8/12
# ...

# %%
# setup network 卷积+卷积+maxpool+全连接 32+64 + 1024 epochs=12
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPool2D
from keras.optimizers import SGD
import datetime,time

model = Sequential()
model.add(Conv2D(32, (3,3), padding='same',  activation='relu', input_shape=(28,28,1)))
print("conv2d_1: ", model.output_shape)
model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
print("conv2d_2: ", model.output_shape)
model.add(MaxPool2D(pool_size=(2,2)))
print("max_pool_1: ", model.output_shape)
model.add(Dropout(0.25))
model.add(Flatten()) # 展开
print("Flatten: ", model.output_shape)
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
print("dense_1: ", model.output_shape)
model.add(Dense(10, activation='softmax')) # 输出
print("output: ", model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=["accuracy"]) # 编译

# train model
import numpy as np
#np.reshape(x_train, (x_train.shape[0], x_train.shape[1], x_train.shape[2], 1))
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
print(x_train.shape)
start_t = datetime.datetime.now()
model.fit(x_train, y_train, epochs=12)
end_t = datetime.datetime.now()
print("cost time: ", end_t-start_t)

# evaluate
x_test = x_test.reshape(x_test.shape[0], x_train.shape[1], x_train.shape[2], 1)
loss_and_acc = model.evaluate(x_test, y_test)
print("loss: ", loss_and_acc[0])
print("accuracy: ", loss_and_acc[1])
# Out:
# W0807 14:25:23.558304 139719089624896 deprecation_wrapper.py:119] From /home/super-workstation/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# conv2d_1:  (None, 28, 28, 32)
# conv2d_2:  (None, 28, 28, 64)
# max_pool_1:  (None, 14, 14, 64)
# Flatten:  (None, 12544)
# dense_1:  (None, 1024)
# output:  (None, 10)
# (60000, 28, 28, 1)
# Epoch 1/12
# 60000/60000 [==============================] - 15s 242us/step - loss: 0.4394 - acc: 0.8664
# Epoch 2/12
# 60000/60000 [==============================] - 15s 251us/step - loss: 0.1951 - acc: 0.9394
# Epoch 3/12
# 60000/60000 [==============================] - 15s 249us/step - loss: 0.1480 - acc: 0.9541
# Epoch 4/12
# 60000/60000 [==============================] - 18s 300us/step - loss: 0.1199 - acc: 0.9632
# Epoch 5/12
# 60000/60000 [==============================] - 18s 296us/step - loss: 0.0984 - acc: 0.9699
# Epoch 6/12
# ...

# %%
# setup network 卷积+maxpool+卷积+maxpool+全连接 32+64 + 1024 epochs=12
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPool2D
from keras.optimizers import SGD
import datetime,time

model = Sequential()
model.add(Conv2D(32, (3,3), padding='same',  activation='relu', input_shape=(28,28,1)))
print("conv2d_1: ", model.output_shape)
model.add(MaxPool2D(pool_size=(2,2)))
print("max_pool_1: ", model.output_shape)
model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
print("conv2d_2: ", model.output_shape)
model.add(MaxPool2D(pool_size=(2,2)))
print("max_pool_2: ", model.output_shape)
model.add(Dropout(0.25))
model.add(Flatten()) # 展开
print("Flatten: ", model.output_shape)
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
print("dense_1: ", model.output_shape)
model.add(Dense(10, activation='softmax')) # 输出
print("output: ", model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=["accuracy"]) # 编译

# train model
import numpy as np
#np.reshape(x_train, (x_train.shape[0], x_train.shape[1], x_train.shape[2], 1))
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
print(x_train.shape)
start_t = datetime.datetime.now()
model.fit(x_train, y_train, epochs=12)
end_t = datetime.datetime.now()
print("cost time: ", end_t-start_t)

# evaluate
x_test = x_test.reshape(x_test.shape[0], x_train.shape[1], x_train.shape[2], 1)
loss_and_acc = model.evaluate(x_test, y_test)
print("loss: ", loss_and_acc[0])
print("accuracy: ", loss_and_acc[1])
# Out:
# conv2d_1:  (None, 28, 28, 32)
# conv2d_2:  (None, 14, 14, 64)
# max_pool_1:  (None, 7, 7, 64)
# Flatten:  (None, 3136)
# dense_1:  (None, 1024)
# output:  (None, 10)
# (60000, 28, 28, 1)
# Epoch 1/12
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.5721 - acc: 0.8196
# Epoch 2/12
# 60000/60000 [==============================] - 8s 126us/step - loss: 0.1875 - acc: 0.9425
# Epoch 3/12
# 60000/60000 [==============================] - 7s 117us/step - loss: 0.1425 - acc: 0.9561
# Epoch 4/12
# 60000/60000 [==============================] - 8s 132us/step - loss: 0.1167 - acc: 0.9628
# Epoch 5/12
# 60000/60000 [==============================] - 9s 147us/step - loss: 0.1008 - acc: 0.9690
# Epoch 6/12
# 60000/60000 [==============================] - 9s 151us/step - loss: 0.0905 - acc: 0.9710
# Epoch 7/12
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.0807 - acc: 0.9746
# Epoch 8/12
# ...

# %%
# setup network 卷积+maxpool+卷积+maxpool+全连接 32+64 + 1024 epochs=12 optimizer='adadelta'
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPool2D
from keras.optimizers import SGD
import datetime,time

model = Sequential()
model.add(Conv2D(32, (3,3), padding='same',  activation='relu', input_shape=(28,28,1)))
print("conv2d_1: ", model.output_shape)
model.add(MaxPool2D(pool_size=(2,2)))
print("max_pool_1: ", model.output_shape)
model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
print("conv2d_2: ", model.output_shape)
model.add(MaxPool2D(pool_size=(2,2)))
print("max_pool_2: ", model.output_shape)
model.add(Dropout(0.25))
model.add(Flatten()) # 展开
print("Flatten: ", model.output_shape)
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
print("dense_1: ", model.output_shape)
model.add(Dense(10, activation='softmax')) # 输出
print("output: ", model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='adadelta', metrics=["accuracy"]) # 编译

# train model
import numpy as np
#np.reshape(x_train, (x_train.shape[0], x_train.shape[1], x_train.shape[2], 1))
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
print(x_train.shape)
start_t = datetime.datetime.now()
model.fit(x_train, y_train, epochs=12)
end_t = datetime.datetime.now()
print("cost time: ", end_t-start_t)

# evaluate
x_test = x_test.reshape(x_test.shape[0], x_train.shape[1], x_train.shape[2], 1)
loss_and_acc = model.evaluate(x_test, y_test)
print("loss: ", loss_and_acc[0])
print("accuracy: ", loss_and_acc[1])
# Out:
# conv2d_1:  (None, 28, 28, 32)
# max_pool_1:  (None, 14, 14, 32)
# conv2d_2:  (None, 14, 14, 64)
# max_pool_2:  (None, 7, 7, 64)
# Flatten:  (None, 3136)
# dense_1:  (None, 1024)
# output:  (None, 10)
# (60000, 28, 28, 1)
# Epoch 1/12
# 60000/60000 [==============================] - 15s 242us/step - loss: 0.1397 - acc: 0.9562
# Epoch 2/12
# 60000/60000 [==============================] - 14s 238us/step - loss: 0.0522 - acc: 0.9839
# Epoch 3/12
# 60000/60000 [==============================] - 14s 226us/step - loss: 0.0399 - acc: 0.9875
# Epoch 4/12
# 60000/60000 [==============================] - 14s 230us/step - loss: 0.0345 - acc: 0.9893
# Epoch 5/12
# 60000/60000 [==============================] - 15s 245us/step - loss: 0.0276 - acc: 0.9909
# Epoch 6/12
# 60000/60000 [==============================] - 15s 243us/step - loss: 0.0259 - acc: 0.9920
# Epoch 7/12
# 60000/60000 [==============================] - 13s 223us/step - loss: 0.0220 - acc: 0.9932
# Epoch 8/12
# ...

# %%
# setup network 卷积+maxpool+卷积+maxpool+全连接 32+64 + 512 epochs=12 optimizer='adadelta'
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPool2D
from keras.optimizers import SGD
import datetime,time

model = Sequential()
model.add(Conv2D(32, (3,3), padding='same',  activation='relu', input_shape=(28,28,1)))
print("conv2d_1: ", model.output_shape)
model.add(MaxPool2D(pool_size=(2,2)))
print("max_pool_1: ", model.output_shape)
model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
print("conv2d_2: ", model.output_shape)
model.add(MaxPool2D(pool_size=(2,2)))
print("max_pool_2: ", model.output_shape)
model.add(Dropout(0.25))
model.add(Flatten()) # 展开
print("Flatten: ", model.output_shape)
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
print("dense_1: ", model.output_shape)
model.add(Dense(10, activation='softmax')) # 输出
print("output: ", model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='adadelta', metrics=["accuracy"]) # 编译

# train model
import numpy as np
#np.reshape(x_train, (x_train.shape[0], x_train.shape[1], x_train.shape[2], 1))
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
print(x_train.shape)
start_t = datetime.datetime.now()
model.fit(x_train, y_train, epochs=12)
end_t = datetime.datetime.now()
print("cost time: ", end_t-start_t)

# evaluate
x_test = x_test.reshape(x_test.shape[0], x_train.shape[1], x_train.shape[2], 1)
loss_and_acc = model.evaluate(x_test, y_test)
print("loss: ", loss_and_acc[0])
print("accuracy: ", loss_and_acc[1])
# Out:
# conv2d_1:  (None, 28, 28, 32)
# max_pool_1:  (None, 14, 14, 32)
# conv2d_2:  (None, 14, 14, 64)
# max_pool_2:  (None, 7, 7, 64)
# Flatten:  (None, 3136)
# dense_1:  (None, 512)
# output:  (None, 10)
# (60000, 28, 28, 1)
# Epoch 1/12
# 60000/60000 [==============================] - 11s 188us/step - loss: 0.1523 - acc: 0.9522
# Epoch 2/12
# 60000/60000 [==============================] - 12s 198us/step - loss: 0.0572 - acc: 0.9820
# Epoch 3/12
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0447 - acc: 0.9860
# Epoch 4/12
# 60000/60000 [==============================] - 13s 211us/step - loss: 0.0364 - acc: 0.9888
# Epoch 5/12
# 60000/60000 [==============================] - 12s 197us/step - loss: 0.0309 - acc: 0.9905
# Epoch 6/12
# 60000/60000 [==============================] - 12s 204us/step - loss: 0.0296 - acc: 0.9909
# Epoch 7/12
# 60000/60000 [==============================] - 12s 204us/step - loss: 0.0257 - acc: 0.9921
# Epoch 8/12
# ...

# %%
# setup network 卷积+maxpool+卷积+maxpool+全连接 32+64 + 256 epochs=12 optimizer='adadelta'
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPool2D
from keras.optimizers import SGD
import datetime,time

model = Sequential()
model.add(Conv2D(32, (3,3), padding='same',  activation='relu', input_shape=(28,28,1)))
print("conv2d_1: ", model.output_shape)
model.add(MaxPool2D(pool_size=(2,2)))
print("max_pool_1: ", model.output_shape)
model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
print("conv2d_2: ", model.output_shape)
model.add(MaxPool2D(pool_size=(2,2)))
print("max_pool_2: ", model.output_shape)
model.add(Dropout(0.25))
model.add(Flatten()) # 展开
print("Flatten: ", model.output_shape)
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
print("dense_1: ", model.output_shape)
model.add(Dense(10, activation='softmax')) # 输出
print("output: ", model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='adadelta', metrics=["accuracy"]) # 编译

# train model
import numpy as np
#np.reshape(x_train, (x_train.shape[0], x_train.shape[1], x_train.shape[2], 1))
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
print(x_train.shape)
start_t = datetime.datetime.now()
model.fit(x_train, y_train, epochs=12)
end_t = datetime.datetime.now()
print("cost time: ", end_t-start_t)

# evaluate
x_test = x_test.reshape(x_test.shape[0], x_train.shape[1], x_train.shape[2], 1)
loss_and_acc = model.evaluate(x_test, y_test)
print("loss: ", loss_and_acc[0])
print("accuracy: ", loss_and_acc[1])
# Out:
# conv2d_1:  (None, 28, 28, 32)
# max_pool_1:  (None, 14, 14, 32)
# conv2d_2:  (None, 14, 14, 64)
# max_pool_2:  (None, 7, 7, 64)
# Flatten:  (None, 3136)
# dense_1:  (None, 256)
# output:  (None, 10)
# (60000, 28, 28, 1)
# Epoch 1/12
# 60000/60000 [==============================] - 12s 203us/step - loss: 0.1612 - acc: 0.9503
# Epoch 2/12
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0638 - acc: 0.9807
# Epoch 3/12
# 60000/60000 [==============================] - 13s 223us/step - loss: 0.0501 - acc: 0.9849
# Epoch 4/12
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0405 - acc: 0.9877
# Epoch 5/12
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0369 - acc: 0.9889
# Epoch 6/12
# 60000/60000 [==============================] - 11s 185us/step - loss: 0.0318 - acc: 0.9903
# Epoch 7/12
# 60000/60000 [==============================] - 11s 186us/step - loss: 0.0306 - acc: 0.9908
# Epoch 8/12
# ...

# %%
# setup network 卷积+maxpool+卷积+maxpool+全连接 32+64 + 128 epochs=12 optimizer='adadelta'
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPool2D
from keras.optimizers import SGD
import datetime,time

model = Sequential()
model.add(Conv2D(32, (3,3), padding='same',  activation='relu', input_shape=(28,28,1)))
print("conv2d_1: ", model.output_shape)
model.add(MaxPool2D(pool_size=(2,2)))
print("max_pool_1: ", model.output_shape)
model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
print("conv2d_2: ", model.output_shape)
model.add(MaxPool2D(pool_size=(2,2)))
print("max_pool_2: ", model.output_shape)
model.add(Dropout(0.25))
model.add(Flatten()) # 展开
print("Flatten: ", model.output_shape)
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
print("dense_1: ", model.output_shape)
model.add(Dense(10, activation='softmax')) # 输出
print("output: ", model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='adadelta', metrics=["accuracy"]) # 编译

# train model
import numpy as np
#np.reshape(x_train, (x_train.shape[0], x_train.shape[1], x_train.shape[2], 1))
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
print(x_train.shape)
start_t = datetime.datetime.now()
model.fit(x_train, y_train, epochs=12)
end_t = datetime.datetime.now()
print("cost time: ", end_t-start_t)

# evaluate
x_test = x_test.reshape(x_test.shape[0], x_train.shape[1], x_train.shape[2], 1)
loss_and_acc = model.evaluate(x_test, y_test)
print("loss: ", loss_and_acc[0])
print("accuracy: ", loss_and_acc[1])
# Out:
# conv2d_1:  (None, 28, 28, 32)
# max_pool_1:  (None, 14, 14, 32)
# conv2d_2:  (None, 14, 14, 64)
# max_pool_2:  (None, 7, 7, 64)
# Flatten:  (None, 3136)
# dense_1:  (None, 128)
# output:  (None, 10)
# (60000, 28, 28, 1)
# Epoch 1/12
# 60000/60000 [==============================] - 13s 219us/step - loss: 0.1958 - acc: 0.9402
# Epoch 2/12
# 60000/60000 [==============================] - 10s 170us/step - loss: 0.0760 - acc: 0.9775
# Epoch 3/12
# 60000/60000 [==============================] - 10s 160us/step - loss: 0.0614 - acc: 0.9817
# Epoch 4/12
# 60000/60000 [==============================] - 13s 218us/step - loss: 0.0521 - acc: 0.9847
# Epoch 5/12
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0478 - acc: 0.9860
# Epoch 6/12
# 60000/60000 [==============================] - 12s 208us/step - loss: 0.0431 - acc: 0.9872
# Epoch 7/12
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.0390 - acc: 0.9887
# Epoch 8/12
# ...

# %%
# setup network 卷积+maxpool+卷积+maxpool+全连接 32+64 + 128 epochs=12 optimizer='rmsprop'
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPool2D
from keras.optimizers import SGD
import datetime,time

model = Sequential()
model.add(Conv2D(32, (3,3), padding='same',  activation='relu', input_shape=(28,28,1)))
print("conv2d_1: ", model.output_shape)
model.add(MaxPool2D(pool_size=(2,2)))
print("max_pool_1: ", model.output_shape)
model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
print("conv2d_2: ", model.output_shape)
model.add(MaxPool2D(pool_size=(2,2)))
print("max_pool_2: ", model.output_shape)
model.add(Dropout(0.25))
model.add(Flatten()) # 展开
print("Flatten: ", model.output_shape)
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
print("dense_1: ", model.output_shape)
model.add(Dense(10, activation='softmax')) # 输出
print("output: ", model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='rmsprop', metrics=["accuracy"]) # 编译

# train model
import numpy as np
#np.reshape(x_train, (x_train.shape[0], x_train.shape[1], x_train.shape[2], 1))
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
print(x_train.shape)
start_t = datetime.datetime.now()
model.fit(x_train, y_train, epochs=12)
end_t = datetime.datetime.now()
print("cost time: ", end_t-start_t)

# evaluate
x_test = x_test.reshape(x_test.shape[0], x_train.shape[1], x_train.shape[2], 1)
loss_and_acc = model.evaluate(x_test, y_test)
print("loss: ", loss_and_acc[0])
print("accuracy: ", loss_and_acc[1])
# Out:
# conv2d_1:  (None, 28, 28, 32)
# max_pool_1:  (None, 14, 14, 32)
# conv2d_2:  (None, 14, 14, 64)
# max_pool_2:  (None, 7, 7, 64)
# Flatten:  (None, 3136)
# dense_1:  (None, 128)
# output:  (None, 10)
# (60000, 28, 28, 1)
# Epoch 1/12
# 60000/60000 [==============================] - 10s 166us/step - loss: 0.1935 - acc: 0.9408
# Epoch 2/12
# 60000/60000 [==============================] - 8s 136us/step - loss: 0.0811 - acc: 0.9768
# Epoch 3/12
# 60000/60000 [==============================] - 12s 196us/step - loss: 0.0712 - acc: 0.9797
# Epoch 4/12
# 60000/60000 [==============================] - 10s 168us/step - loss: 0.0707 - acc: 0.9803
# Epoch 5/12
# 60000/60000 [==============================] - 11s 183us/step - loss: 0.0720 - acc: 0.9800
# Epoch 6/12
# 60000/60000 [==============================] - 9s 149us/step - loss: 0.0775 - acc: 0.9794
# Epoch 7/12
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0826 - acc: 0.9779
# Epoch 8/12
# ...

# %%
# setup network 卷积+maxpool+卷积+maxpool+全连接 32+64 + 1024 epochs=12 optimizer='rmsprop'
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPool2D
from keras.optimizers import SGD
import datetime,time

model = Sequential()
model.add(Conv2D(32, (3,3), padding='same',  activation='relu', input_shape=(28,28,1)))
print("conv2d_1: ", model.output_shape)
model.add(MaxPool2D(pool_size=(2,2)))
print("max_pool_1: ", model.output_shape)
model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
print("conv2d_2: ", model.output_shape)
model.add(MaxPool2D(pool_size=(2,2)))
print("max_pool_2: ", model.output_shape)
model.add(Dropout(0.25))
model.add(Flatten()) # 展开
print("Flatten: ", model.output_shape)
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
print("dense_1: ", model.output_shape)
model.add(Dense(10, activation='softmax')) # 输出
print("output: ", model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='rmsprop', metrics=["accuracy"]) # 编译

# train model
import numpy as np
#np.reshape(x_train, (x_train.shape[0], x_train.shape[1], x_train.shape[2], 1))
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
print(x_train.shape)
start_t = datetime.datetime.now()
model.fit(x_train, y_train, epochs=12)
end_t = datetime.datetime.now()
print("cost time: ", end_t-start_t)

# evaluate
x_test = x_test.reshape(x_test.shape[0], x_train.shape[1], x_train.shape[2], 1)
loss_and_acc = model.evaluate(x_test, y_test)
print("loss: ", loss_and_acc[0])
print("accuracy: ", loss_and_acc[1])
# Out:
# conv2d_1:  (None, 28, 28, 32)
# max_pool_1:  (None, 14, 14, 32)
# conv2d_2:  (None, 14, 14, 64)
# max_pool_2:  (None, 7, 7, 64)
# Flatten:  (None, 3136)
# dense_1:  (None, 1024)
# output:  (None, 10)
# (60000, 28, 28, 1)
# Epoch 1/12
# 60000/60000 [==============================] - 15s 244us/step - loss: 0.1310 - acc: 0.9602
# Epoch 2/12
# 60000/60000 [==============================] - 12s 204us/step - loss: 0.0591 - acc: 0.9826
# Epoch 3/12
# 60000/60000 [==============================] - 13s 212us/step - loss: 0.0535 - acc: 0.9846
# Epoch 4/12
# 60000/60000 [==============================] - 11s 185us/step - loss: 0.0509 - acc: 0.9850
# Epoch 5/12
# 60000/60000 [==============================] - 13s 210us/step - loss: 0.0497 - acc: 0.9867
# Epoch 6/12
# 60000/60000 [==============================] - 12s 203us/step - loss: 0.0521 - acc: 0.9857
# Epoch 7/12
# 60000/60000 [==============================] - 13s 208us/step - loss: 0.0508 - acc: 0.9861
# Epoch 8/12
# ...

# %%
# setup network 卷积+maxpool+卷积+maxpool+全连接 32+64 + 1024 epochs=12 optimizer='adagrad'
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPool2D
from keras.optimizers import SGD
import datetime,time

model = Sequential()
model.add(Conv2D(32, (3,3), padding='same',  activation='relu', input_shape=(28,28,1)))
print("conv2d_1: ", model.output_shape)
model.add(MaxPool2D(pool_size=(2,2)))
print("max_pool_1: ", model.output_shape)
model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
print("conv2d_2: ", model.output_shape)
model.add(MaxPool2D(pool_size=(2,2)))
print("max_pool_2: ", model.output_shape)
model.add(Dropout(0.25))
model.add(Flatten()) # 展开
print("Flatten: ", model.output_shape)
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
print("dense_1: ", model.output_shape)
model.add(Dense(10, activation='softmax')) # 输出
print("output: ", model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='adagrad', metrics=["accuracy"]) # 编译

# train model
import numpy as np
#np.reshape(x_train, (x_train.shape[0], x_train.shape[1], x_train.shape[2], 1))
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
print(x_train.shape)
start_t = datetime.datetime.now()
model.fit(x_train, y_train, epochs=12)
end_t = datetime.datetime.now()
print("cost time: ", end_t-start_t)

# evaluate
x_test = x_test.reshape(x_test.shape[0], x_train.shape[1], x_train.shape[2], 1)
loss_and_acc = model.evaluate(x_test, y_test)
print("loss: ", loss_and_acc[0])
print("accuracy: ", loss_and_acc[1])
# Out:
# conv2d_1:  (None, 28, 28, 32)
# max_pool_1:  (None, 14, 14, 32)
# conv2d_2:  (None, 14, 14, 64)
# max_pool_2:  (None, 7, 7, 64)
# Flatten:  (None, 3136)
# dense_1:  (None, 1024)
# output:  (None, 10)
# (60000, 28, 28, 1)
# Epoch 1/12
# 60000/60000 [==============================] - 13s 209us/step - loss: 0.1251 - acc: 0.9618
# Epoch 2/12
# 60000/60000 [==============================] - 13s 211us/step - loss: 0.0484 - acc: 0.9849
# Epoch 3/12
# 60000/60000 [==============================] - 11s 191us/step - loss: 0.0372 - acc: 0.9883
# Epoch 4/12
# 60000/60000 [==============================] - 12s 199us/step - loss: 0.0316 - acc: 0.9903
# Epoch 5/12
# 60000/60000 [==============================] - 10s 172us/step - loss: 0.0276 - acc: 0.9917
# Epoch 6/12
# 60000/60000 [==============================] - 12s 195us/step - loss: 0.0245 - acc: 0.9926
# Epoch 7/12
# 60000/60000 [==============================] - 11s 191us/step - loss: 0.0223 - acc: 0.9928
# Epoch 8/12
# ...

# %%
# setup network 卷积+maxpool+卷积+maxpool+全连接 32+64 + 1024 epochs=12 optimizer='adam'
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPool2D
from keras.optimizers import SGD
import datetime,time

model = Sequential()
model.add(Conv2D(32, (3,3), padding='same',  activation='relu', input_shape=(28,28,1)))
print("conv2d_1: ", model.output_shape)
model.add(MaxPool2D(pool_size=(2,2)))
print("max_pool_1: ", model.output_shape)
model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
print("conv2d_2: ", model.output_shape)
model.add(MaxPool2D(pool_size=(2,2)))
print("max_pool_2: ", model.output_shape)
model.add(Dropout(0.25))
model.add(Flatten()) # 展开
print("Flatten: ", model.output_shape)
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
print("dense_1: ", model.output_shape)
model.add(Dense(10, activation='softmax')) # 输出
print("output: ", model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=["accuracy"]) # 编译

# train model
import numpy as np
#np.reshape(x_train, (x_train.shape[0], x_train.shape[1], x_train.shape[2], 1))
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
print(x_train.shape)
start_t = datetime.datetime.now()
model.fit(x_train, y_train, epochs=12)
end_t = datetime.datetime.now()
print("cost time: ", end_t-start_t)

# evaluate
x_test = x_test.reshape(x_test.shape[0], x_train.shape[1], x_train.shape[2], 1)
loss_and_acc = model.evaluate(x_test, y_test)
print("loss: ", loss_and_acc[0])
print("accuracy: ", loss_and_acc[1])
# Out:
# conv2d_1:  (None, 28, 28, 32)
# max_pool_1:  (None, 14, 14, 32)
# conv2d_2:  (None, 14, 14, 64)
# max_pool_2:  (None, 7, 7, 64)
# Flatten:  (None, 3136)
# dense_1:  (None, 1024)
# output:  (None, 10)
# (60000, 28, 28, 1)
# Epoch 1/12
# 60000/60000 [==============================] - 16s 263us/step - loss: 0.1336 - acc: 0.9583
# Epoch 2/12
# 60000/60000 [==============================] - 14s 236us/step - loss: 0.0522 - acc: 0.9835
# Epoch 3/12
# 60000/60000 [==============================] - 14s 239us/step - loss: 0.0405 - acc: 0.9874
# Epoch 4/12
# 60000/60000 [==============================] - 14s 233us/step - loss: 0.0327 - acc: 0.9896
# Epoch 5/12
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.0278 - acc: 0.9912
# Epoch 6/12
# 60000/60000 [==============================] - 13s 218us/step - loss: 0.0242 - acc: 0.9923
# Epoch 7/12
# 60000/60000 [==============================] - 13s 212us/step - loss: 0.0215 - acc: 0.9930
# Epoch 8/12
# ...

# %%
# setup network 卷积+maxpool+卷积+maxpool+全连接 32+64 + 1024 epochs=12 optimizer='adamax'
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPool2D
from keras.optimizers import SGD
import datetime,time

model = Sequential()
model.add(Conv2D(32, (3,3), padding='same',  activation='relu', input_shape=(28,28,1)))
print("conv2d_1: ", model.output_shape)
model.add(MaxPool2D(pool_size=(2,2)))
print("max_pool_1: ", model.output_shape)
model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
print("conv2d_2: ", model.output_shape)
model.add(MaxPool2D(pool_size=(2,2)))
print("max_pool_2: ", model.output_shape)
model.add(Dropout(0.25))
model.add(Flatten()) # 展开
print("Flatten: ", model.output_shape)
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
print("dense_1: ", model.output_shape)
model.add(Dense(10, activation='softmax')) # 输出
print("output: ", model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='adamax', metrics=["accuracy"]) # 编译

# train model
import numpy as np
#np.reshape(x_train, (x_train.shape[0], x_train.shape[1], x_train.shape[2], 1))
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
print(x_train.shape)
start_t = datetime.datetime.now()
model.fit(x_train, y_train, epochs=12)
end_t = datetime.datetime.now()
print("cost time: ", end_t-start_t)

# evaluate
x_test = x_test.reshape(x_test.shape[0], x_train.shape[1], x_train.shape[2], 1)
loss_and_acc = model.evaluate(x_test, y_test)
print("loss: ", loss_and_acc[0])
print("accuracy: ", loss_and_acc[1])
# Out:
# conv2d_1:  (None, 28, 28, 32)
# max_pool_1:  (None, 14, 14, 32)
# conv2d_2:  (None, 14, 14, 64)
# max_pool_2:  (None, 7, 7, 64)
# Flatten:  (None, 3136)
# dense_1:  (None, 1024)
# output:  (None, 10)
# (60000, 28, 28, 1)
# Epoch 1/12
# 60000/60000 [==============================] - 14s 226us/step - loss: 0.1416 - acc: 0.9555
# Epoch 2/12
# 60000/60000 [==============================] - 11s 184us/step - loss: 0.0561 - acc: 0.9824
# Epoch 3/12
# 60000/60000 [==============================] - 12s 203us/step - loss: 0.0417 - acc: 0.9873
# Epoch 4/12
# 60000/60000 [==============================] - 12s 200us/step - loss: 0.0334 - acc: 0.9893
# Epoch 5/12
# 60000/60000 [==============================] - 12s 202us/step - loss: 0.0273 - acc: 0.9913
# Epoch 6/12
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0234 - acc: 0.9922
# Epoch 7/12
# 60000/60000 [==============================] - 12s 201us/step - loss: 0.0201 - acc: 0.9933
# Epoch 8/12
# ...

# %%
# setup network 卷积+maxpool+卷积+maxpool+全连接 32+64 + 1024 epochs=12 optimizer='nadam'
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPool2D
from keras.optimizers import SGD
import datetime,time

model = Sequential()
model.add(Conv2D(32, (3,3), padding='same',  activation='relu', input_shape=(28,28,1)))
print("conv2d_1: ", model.output_shape)
model.add(MaxPool2D(pool_size=(2,2)))
print("max_pool_1: ", model.output_shape)
model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
print("conv2d_2: ", model.output_shape)
model.add(MaxPool2D(pool_size=(2,2)))
print("max_pool_2: ", model.output_shape)
model.add(Dropout(0.25))
model.add(Flatten()) # 展开
print("Flatten: ", model.output_shape)
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
print("dense_1: ", model.output_shape)
model.add(Dense(10, activation='softmax')) # 输出
print("output: ", model.output_shape)

sgd=SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer='nadam', metrics=["accuracy"]) # 编译

# train model
import numpy as np
#np.reshape(x_train, (x_train.shape[0], x_train.shape[1], x_train.shape[2], 1))
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
print(x_train.shape)
start_t = datetime.datetime.now()
model.fit(x_train, y_train, epochs=12)
end_t = datetime.datetime.now()
print("cost time: ", end_t-start_t)

# evaluate
x_test = x_test.reshape(x_test.shape[0], x_train.shape[1], x_train.shape[2], 1)
loss_and_acc = model.evaluate(x_test, y_test)
print("loss: ", loss_and_acc[0])
print("accuracy: ", loss_and_acc[1])
# Out:
# conv2d_1:  (None, 28, 28, 32)
# max_pool_1:  (None, 14, 14, 32)
# conv2d_2:  (None, 14, 14, 64)
# max_pool_2:  (None, 7, 7, 64)
# Flatten:  (None, 3136)
# dense_1:  (None, 1024)
# output:  (None, 10)
# (60000, 28, 28, 1)
# Epoch 1/12
# 60000/60000 [==============================] - 16s 261us/step - loss: 0.1237 - acc: 0.9607
# Epoch 2/12
# 60000/60000 [==============================] - 15s 245us/step - loss: 0.0562 - acc: 0.9822
# Epoch 3/12
# 60000/60000 [==============================] - 15s 249us/step - loss: 0.0484 - acc: 0.9856
# Epoch 4/12
# 60000/60000 [==============================] - 14s 241us/step - loss: 0.0415 - acc: 0.9876
# Epoch 5/12
# 60000/60000 [==============================] - 14s 233us/step - loss: 0.0371 - acc: 0.9892
# Epoch 6/12
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.0330 - acc: 0.9899
# Epoch 7/12
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.0314 - acc: 0.9911
# Epoch 8/12
# ...
