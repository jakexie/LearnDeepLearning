# %%
# read dataset pascal
import matplotlib.pyplot as plt
import numpy as np
import scipy.io as scio
import sys
#print(sys.path)
sys.path.insert(0, '../')
from dpl import utils
from dpl.data.pascal import preprocessing
#image_dir = "/home/super-workstation/Data/pascal/benchmark_RELEASE/dataset/cls/2008_000007.mat"
image_root = "/home/super-workstation/Data/pascal/VOC_Data/VOC2012/"
#train_list = image_root + "train.txt"
#val_list = image_root + "val.txt"

# 标签数据预处理
#preprocessing.split_label_into_masks("/home/super-workstation/Data/pascal/VOC_Data/VOC2012/SegmentationClass", "/mask1/")

import os
import cv2
    
class PascalDataset:
    def __init__(self, path, is_train=True):
        self.__is_train = is_train
        self.__path = path
        self.__id2filename = self.__get_filename_list(path)
        self.image_ids = list(range(len(self.__id2filename)))
    def __get_filename_list(self, path):
        txt_fname = '%s/ImageSets/Segmentation/%s' % (
        path, 'train.txt' if self.__is_train else 'val.txt')
        images = []
        with open(txt_fname, 'r') as f:
            images = f.read().split()
        return images
    
    def load_image(self, image_id):
        filename = self.__id2filename[image_id]
        full_path = '%s/JPEGImages/%s.jpg' % (self.__path, filename)
        return cv2.imread(full_path)#np.array(Image.open(full_path))
        
    #加载图片对应的分类mask
    def load_mask(self, image_id):
        filename = self.__id2filename[image_id]
        full_dir = '%s/SegmentationClass/%s/%s' % (self.__path, "mask", filename)
        masks = []
        class_ids = []
        files = os.listdir(full_dir)
        # 单张图片可能有多个类别，每个类别对应一张mask
        for mask_name in files:
            #print(os.path.splitext(image_name)[0])
            if os.path.splitext(mask_name)[1] == '.png':
                mask_tmp = cv2.imread(full_dir + "/" + mask_name, cv2.IMREAD_GRAYSCALE).astype(np.bool)
                masks.append(mask_tmp)
                class_ids.append(int(os.path.splitext(mask_name)[0]))
        masks = np.stack(masks, axis=-1)
        return masks, class_ids

class Config:
    # image size
    image_min_dims = 512
    image_max_dims = 512
    steps_each_epoch = 65
    batch_size = 16
    epoches =100
    shuffle = True
    num_classes = 21

# 加载源数据并根据config 缩放+padding(不改变原图内容相对比例)
def load_image_and_mask(dataset, config, image_id):    
    image = dataset.load_image(image_id)
    mask, class_ids = dataset.load_mask(image_id)
    
    image, window, scale, padding, crop = utils.resize_image(
        image,
        min_dim=config.image_min_dims,
        max_dim=config.image_max_dims)
    
    mask = utils.resize_mask(mask, scale, padding, crop)
    return image, mask, class_ids

# 数据生成器（方便批次训练）
def data_generator(dataset, config):
    
    image_index = -1
    image_ids = dataset.image_ids
    #print("image_ids-->", image_ids)
    b = 0
    while True:
        # 每个epoch开始混淆数据顺序
        image_index = (image_index+1)%len(image_ids)
        if image_index == 0 and config.shuffle:
            np.random.shuffle(image_ids)
        image_id = image_ids[image_index]
        # 加载图像和mask
        image, masks, class_ids = load_image_and_mask(dataset, config, image_id)
        
        if b == 0:
            batch_images = np.zeros((config.batch_size,)+image.shape, dtype = image.dtype)
            batch_masks = np.zeros((config.batch_size, mask.shape[0], 
                                    mask.shape[1], config.num_classes), dtype=mask.dtype)
        batch_images[b] = image
        count = 0
        for i in class_ids:
            batch_masks[b,:,:,i] = mask[:,:,count]
        
        b+=1
        # 已读取完成1个batch的数据
        if b >=  config.batch_size:
            inputs = batch_images
            outputs = batch_masks
            
            yield(inputs, outputs)
            b = 0

config = Config()
dataset = PascalDataset("/home/super-workstation/Data/pascal/VOC_Data/VOC2012")
image, mask, class_ids = load_image_and_mask(dataset,config,0)

train_generator = data_generator(dataset, config)
'''    
num_classes = 21
crop_size = (300, 500) #height width
print("load data ...")
(features_t, labels_t) = preprocessing.read_voc_images_with_filter(image_root, crop_size)
(features_v, labels_v) = preprocessing.read_voc_images_with_filter(image_root, crop_size, False)

print("crop data ...")
train_data = np.zeros((len(features_t), crop_size[0], crop_size[1], 3), dtype='uint8')
train_label = np.zeros((len(features_t), crop_size[0], crop_size[1]), dtype='uint8')
test_data = np.zeros((len(features_v), crop_size[0], crop_size[1], 3), dtype='uint8')
test_label = np.zeros((len(features_v), crop_size[0], crop_size[1]), dtype='uint8')
for i in range(len(features_t)):
    (crop_feat, crop_label) = preprocessing.voc_rand_crop(features_t[i], labels_t[i], crop_size)
    train_data[i] = crop_feat
    train_label[i] = crop_label
for j in range(len(features_v)):
    (crop_feat, crop_label) = preprocessing.voc_rand_crop(features_v[j], labels_v[j], crop_size)
    test_data[j] = crop_feat
    test_label[j] = crop_label

plt.imshow(test_label[0])#, cmap=plt.cm.binary)
plt.show()

#x = np.zeros(21)
#train_label = np.expand_dims(x, axis=4)
#train_label = train_label[..., -1]
def int2hot(a, num_classes = 21):
    one_hot = np.zeros(num_classes)
    if a != 0 and a != 255: #忽略255边界
        one_hot[a] = 1
    return one_hot
def get_one_hot(label, num_classes):
    label_one_hot = np.zeros((label.shape[0], label.shape[1], label.shape[2], num_classes), dtype='uint8')
    for i in range(label.shape[0]):
        for j in range(label.shape[1]):
            for k in range(label.shape[2]):
                #one_hot = int2hot(label[i][j][k], num_classes)
                #label_one_hot[i][j][k] = one_hot
                if label[i][j][k]!=0 and label[i][j][k]!=255:
                    label_one_hot[i][j][k][label[i][j][k]] = 1
    return label_one_hot

print("convert label to one-hot ...")
# 将标签转换成 one hot 编码
train_one_hot_label = get_one_hot(train_label, num_classes)
test_one_hot_label = get_one_hot(test_label, num_classes)

print(train_label.shape)
print("train list: ", len(train_data))
print("test list: ", len(test_data))

print("train label: ", train_one_hot_label.shape)
print("test label: ", test_one_hot_label.shape)

'''

# convert list to numpy
'''
min_x = 10000
min_y = 10000
for i in range(len(features_t)):
    min_x = min(min_x, features_t[i].shape[0])
    min_y = min(min_y, features_t[i].shape[1])

for j in range(len(features_v)):
    min_x = min(min_x, features_v[j].shape[0])
    min_y = min(min_y, features_v[j].shape[1])

print(min_x, min_y)
'''

'''
for i in range(5):
    (crop_feat, crop_label) = preprocessing.voc_rand_crop(features_t[0], labels_t[0], crop_size)
    plt.imshow(crop_label)#, cmap=plt.cm.binary)
    plt.show()
    plt.imshow(crop_feat)#, cmap=plt.cm.binary)
    plt.show()
'''

'''
print(len(features))
utils.showSingleImage(labels[0])

colormap2label = preprocessing.build_colormap2label()

label = label*255
label = label.astype('uint8')
'''

'''
for i in range(label.shape[0]):
    for j in range(label.shape[1]):
        pixel = label[i][j]
        if pixel != 0 and pixel != 255:
            print(pixel)
            print(preprocessing.VOC_CLASSES[pixel])
            #idx=pixel
            #index = colormap2label[idx]
            #print(index)
'''

#label_grey = preprocessing.voc_label_indices(label, colormap2label)
#utils.showSingleImage(label_grey)

'''
data = scio.loadmat(image_dir)
print(type(data))
st = data['GTcls']
seg = st['Segmentation']
print(seg.shape)
cater_current = st['CategoriesPresent']
print(cater_current)
#for key, value in data.iteritems() :
#    print(key, value)

image = seg[0][0]

count = 0
for i in range(image.shape[0]):
    for j in range(image.shape[1]):
        if image[i][j] != 0:
            count+=1
print(count)

plt.imshow(image)#, cmap=plt.cm.binary)
plt.show()
#utils.showSingleImage(image)
#print(seg)
'''
# Out:
# (512, 512, 3)
# (512, 512, 2)
# info:
# image size -->  512 x 512
# channels -->  3
# info:
# image size -->  512 x 512
# (16, 512, 512, 3) (16, 512, 512, 21)
# (16, 512, 512, 3) (16, 512, 512, 21)
# (16, 512, 512, 3) (16, 512, 512, 21)
# (16, 512, 512, 3) (16, 512, 512, 21)
# (16, 512, 512, 3) (16, 512, 512, 21)
# "\ndata = scio.loadmat(image_dir)\nprint(type(data))\nst = data['GTcls']\nseg = st['Segmentation']\nprint(seg.shape)\ncater_current = st['CategoriesPresent']\nprint(cater_current)\n#for key, value in data.iteritems() :\n#    print(key, value)\n\nimage = seg[0][0]\n\ncount = 0\nfor i in range(image.shape[0]):\n    for j in range(image.shape[1]):\n        if image[i][j] != 0:\n            count+=1\nprint(count)\n\nplt.imshow(image)#, cmap=plt.cm.binary)\nplt.show()\n#utils.showSingleImage(image)\n#print(seg)\n"

# %%
# fcn 32s
# 直接从 pool5 上采样（反卷级）到原尺寸
# 5 layers
from keras.models import Model, Sequential
from keras.layers import Conv2D, Conv2DTranspose, MaxPooling2D, Dropout, UpSampling2D
from keras.layers import Input, ZeroPadding2D, BatchNormalization, Activation

def conv2d_bn(input, nums_kernal, size, strides=1, padding = 'same'):
    x = Conv2D(nums_kernal, size, padding=padding, strides=strides)(input)
    x = BatchNormalization()(x)
    return Activation('relu')(x)

# model = Sequential()
# preprocessing
input = Input(shape=(crop_size[0],crop_size[1],3))
#x = ZeroPadding2D(100)(input)
# layer1 2conv  1/2
x = conv2d_bn(input, 64, (3,3))
x = conv2d_bn(x, 64, (3,3))
pool1 = MaxPooling2D()(x)

# layer2 2conv 1/4
x = conv2d_bn(pool1, 128, (3,3))
x = conv2d_bn(x, 128, (3,3))
pool2 = MaxPooling2D()(x)

# layer3 3conv 1/8
x = conv2d_bn(pool2, 256, (3,3))
x = conv2d_bn(x, 256, (3,3))
x = conv2d_bn(x, 256, (3,3))
pool3 = MaxPooling2D()(x)

# layer4 3conv 1/16
x = conv2d_bn(pool3, 256, (3,3))
x = conv2d_bn(x, 256, (3,3))
x = conv2d_bn(x, 256, (3,3))
pool4 = MaxPooling2D()(x)

# layer5 3conv 1/32
x = conv2d_bn(pool4, 256, (3,3))
x = conv2d_bn(x, 256, (3,3))
x = conv2d_bn(x, 256, (3,3))
pool5 = MaxPooling2D()(x)

# layer6 2full
full_1 = conv2d_bn(pool5, 4096, (1,1), padding='valid')
drop_1 = Dropout(0.5)(full_1)
full_2 = conv2d_bn(drop_1, 4096, (1,1), padding='valid')
drop_2 = Dropout(0.5)(full_2)

# 上采样32倍
drop_2_n = conv2d_bn(drop_1, 21, (1,1), padding='valid')
#deconv_1 = Conv2DTranspose(21, (64,64), strides=32)(drop_2_n)

ratio = (int(input.shape[1].value/drop_2_n.shape[1].value), int(input.shape[2].value/drop_2_n.shape[2].value))
#print(ratio)
bilinear_inter_1 = UpSampling2D(ratio)(drop_2_n)
deconv_1 = conv2d_bn(bilinear_inter_1, 21, (3,3))

output=Activation('softmax')(deconv_1)

model = Model(input, output, name='fcn_net')
model.summary()

model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

from keras.utils import plot_model
plot_model(model, to_file='fcn_net_model.png', show_shapes=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         (None, 300, 500, 3)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 300, 500, 64)      1792
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 300, 500, 64)      256
# _________________________________________________________________
# activation_19 (Activation)   (None, 300, 500, 64)      0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 300, 500, 64)      36928
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 300, 500, 64)      256
# _________________________________________________________________
# activation_20 (Activation)   (None, 300, 500, 64)      0
# ...

# %%
utils.trainAndEvaluateData(model, train_data, train_one_hot_label, test_data, test_one_hot_label)
# Out:
# Train on 1310 samples, validate on 146 samples
# Epoch 1/12
# 1310/1310 [==============================] - 30s 23ms/step - loss: 1.1572 - acc: 0.0720 - val_loss: 1.2149 - val_acc: 0.0748
# Epoch 2/12
# 1310/1310 [==============================] - 18s 14ms/step - loss: 1.1087 - acc: 0.0834 - val_loss: 1.2073 - val_acc: 0.0656
# Epoch 3/12
# 1310/1310 [==============================] - 19s 14ms/step - loss: 1.0775 - acc: 0.0849 - val_loss: 1.1802 - val_acc: 0.0593
# Epoch 4/12
# 1310/1310 [==============================] - 18s 14ms/step - loss: 1.0496 - acc: 0.0912 - val_loss: 1.0812 - val_acc: 0.0823
# Epoch 5/12
# 1310/1310 [==============================] - 18s 14ms/step - loss: 1.0207 - acc: 0.0953 - val_loss: 1.1271 - val_acc: 0.1184
# Epoch 6/12
# 1310/1310 [==============================] - 18s 14ms/step - loss: 1.0017 - acc: 0.0963 - val_loss: 0.9826 - val_acc: 0.1184
# Epoch 7/12
# ...

# %%
# u-net
import keras
from keras.models import Model
from keras.layers import Conv2D, Dense, MaxPooling2D, UpSampling2D
from keras.layers import Activation, Input, BatchNormalization

def conv2d_bn(input, nums_kernal, size, strides=1, padding = 'same'):
    x = Conv2D(nums_kernal, size, padding=padding, strides=strides)(input)
    x = BatchNormalization()(x)
    return Activation('relu')(x)

def upsample_contract(input_1, input_2, nums_kernel, kernel_size=(3,3)):
    up_ratio = (int(input_2.shape[1].value/input_1.shape[1].value), 
                int(input_2.shape[2].value/input_1.shape[2].value))
    upsample = UpSampling2D(up_ratio)(input_1)
    conv = conv2d_bn(upsample, nums_kernel, kernel_size)
    concat = keras.layers.concatenate([conv, input_2])
    return concat

input = Input(shape=(input_height, input_width, 3))
# layer 1
conv_1a = conv2d_bn(input, 64, (3,3))
conv_1b = conv2d_bn(conv_1a, 64, (3,3))
pooling_1 = MaxPooling2D()(conv_1b)
# layer 2
conv_2a = conv2d_bn(pooling_1, 128, (3,3))
conv_2b = conv2d_bn(conv_2a, 128, (3,3))
pooling_2 = MaxPooling2D()(conv_2b)
# layer 3
conv_3a = conv2d_bn(pooling_2, 256, (3,3))
conv_3b = conv2d_bn(conv_3a, 256, (3,3))
pooling_3 = MaxPooling2D()(conv_3b)
# layer 4
conv_4a = conv2d_bn(pooling_3, 512, (3,3))
conv_4b = conv2d_bn(conv_4a, 512, (3,3))
pooling_4 = MaxPooling2D()(conv_4b)
# layer 5
conv_5a = conv2d_bn(pooling_4, 1024, (3,3))
conv_5b = conv2d_bn(conv_5a, 1024, (3,3))
#pooling_5 = MaxPooling2D()(conv_5b)

# inv_layer 4
de_conv_4a = upsample_contract(conv_5b, conv_4b, 512)
de_conv_4b = conv2d_bn(de_conv_4a, 512, (3,3))
de_conv_4c = conv2d_bn(de_conv_4b, 512, (3,3))

# inv_layer 3
de_conv_3a = upsample_contract(de_conv_4c, conv_3b, 256)
de_conv_3b = conv2d_bn(de_conv_3a, 256, (3,3))
de_conv_3c = conv2d_bn(de_conv_3b, 256, (3,3))

# inv_layer 2
de_conv_2a = upsample_contract(de_conv_3c, conv_2b, 128)
de_conv_2b = conv2d_bn(de_conv_2a, 128, (3,3))
de_conv_2c = conv2d_bn(de_conv_2b, 128, (3,3))

# inv_layer 1
de_conv_1a = upsample_contract(de_conv_2c, conv_1b, 128)
de_conv_1b = conv2d_bn(de_conv_1a, 128, (3,3))
de_conv_1c = conv2d_bn(de_conv_1b, 128, (3,3))

# output
output = conv2d_bn(de_conv_1c, 21, (1,1))

model = Model(input, output, name='u-net')

model.summary()

model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_6 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 224, 224, 64) 1792        input_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 224, 224, 64) 256         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 224, 224, 64) 0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 224, 224, 64) 36928       activation_90[0][0]
# ...

# %%
utils.trainAndEvaluateData(model, train_data, train_one_hot_label, test_data, test_one_hot_label， 12， batch_size = 16)
# Out:
# Train on 1310 samples, validate on 146 samples
# Epoch 1/12
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-13-70f212ff5cc8> in <module>
# ----> 1 utils.trainAndEvaluateData(model, train_data, train_one_hot_label, test_data, test_one_hot_label)
#
# ~/program/LearnDeepLearning/src/dpl/utils.py in trainAndEvaluateData(model, train_data, train_label, test_data, test_label, epochs)
#      68 def trainAndEvaluateData(model, train_data, train_label, test_data, test_label, epochs=12):
#      69     start_tm = datetime.datetime.now()
# ---> 70     history = model.fit(train_data, train_label, validation_split=0.1, epochs=epochs)
#      71     end_tm = datetime.datetime.now()
#      72     print("cost: ", (end_tm-start_tm).seconds)
#
# ...
